# %% [markdown]
# # GNUMERIC PERMITE REALIZAR PRONÓSTICOS QUE SUPERAN A EXCEL

# %% [markdown]
# Vamos a hacer el pronóstico de como evolucionará el mundo digital para 2025 y 2030 a partir de como ha evolucionado en los últimos años utilizando Gnumeric.

# %%
library(readr)

# %%
library(readxl)

# %%
universodigital <- read.csv("Documents/economiaSftw/datos/digitalUniverseSize.csv")

# %%
universodigital
# Out:
#   agno exabytes
# 1 2005   130
# 2 2010  1200
# 3 2015  7900
# 4 2020 40900

# %% [markdown]
# Graficamos la evlución del universo digital y le agregamos la recta de regresión y la ecuación de regresión

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Ahora, calculamos los pronósticos a partir de la ecuación de regresión.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Ahora graficamos los pronósticos

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Por lo tanto, el pronóstico nos indica que para 2030 existirán 2.16 Billones de exabytes.

# %% [markdown]
# https://alejandroalegriamatus.imgur.com/all

# %% [markdown]
# FIN
